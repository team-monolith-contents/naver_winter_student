# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; background-color: #dff0d8; border-color: #d6e9c6; font-weight: bold;">
#     <br><br>
#     <div style="font-weight: bold; font-size: 40px">인공지능 윤리</div>
#     <div style="font-weight: bold; font-size: 20px">[08] 안전하고 신뢰할 수 있는 인공지능</div>
#     <hr style="width:80%;text-align:left;margin-left:0;border:0.5px solid green">
#     <활동 목표>
#         <br>안전한 인공지능을 만들기 위해 신뢰성을 높일 수 있다.<br><br>
#         [활동 1] 교통표지판 인식 정확도 높이기<br>
#         [활동 2] 파이썬을 활용하여 교통표지판 인식 모델 구현하기<br>
# </div>

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; border-color: #d6e9c6; font-weight: bold;"><h2 style='font-weight: bold'>0. 자율주행 자동차는 안전할까?</h2></div>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 자율주행 자동차가 표지판과 사람 등 주변 사물을 스스로 인식하며 주행하고 있습니다.
#
# 직진을 하다가 앞에 서있는 트럭 옆면을 보고 빛으로 착각하여 트럭과 충돌하는 사고가 발생합니다.
#
# 왜 이런일이 발생하였을까요?
#
# 왜 자동차는 트럭을 인식하지 못했을까요?
#
# 이것은 화창한 날씨에 햇빛과 트럭의 흰색 옆면을 구분하지 못하여 발생한 사고입니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 자율주행 자동차가 인식해야 하는 물체에는 무엇이 있을까요?
#
# 차량, 사람, 신호등, 표지판, 도로 등 주변 물체 모두를 인식해야 합니다.
#
# 자율주행 자동차에게 물체 인식은 매우 중요한 기술입니다.
#
# 물체를 잘못 인식하여 우리의 안전을 위협할 수 있기 때문이지요.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 안전한 인공지능을 만들기 위해 동작의 무엇이 중요할까요?
#
# 정답은 신뢰도 혹은 정확도입니다.
#
# 정확하게 물체를 구분하여 동작하게 된다면 안전하게 이용할 수 있습니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 인공지능이 잘못된 판단을 내렸을 때, 우리의 안전을 위협할 수 있습니다.
#
# 안면 인식 기술을 통해 보안을 해제할 때, 잘못 인식한다면 무슨 문제가 발생할까요?
# 우리의 개인정보가 유출되거나 사생활이 침해되고 금융 피해가 생길 수도 있습니다.
#
# 적군 얼굴을 인식하는 소프트웨어가 탑재된 자율형 전투 무기의 경우, 잘못 인식한다면 무슨 문제가 발생할까요?
# 우리의 생명과 안전에 큰 위협을 줄 수 있습니다.
#
# 의료 분야에서 CT 촬영 결과를 잘못 인식하여 잘못된 판단을 한다면 무슨 문제가 발생할까요?
# 환자에게 전혀 맞지 않는 처방을 내려 우리의 안전을 위협할 수도 있습니다.
#
# 이처럼 인공지능 동작의 신뢰성은 우리의 안전성과 큰 연관이 있습니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 인공지능의 오작동으로 인해 우리의 안전성을 위협할 수 있음을 보았습니다.
#
# 이와 같은 특성은 인공지능 윤리 10대 원칙 중 ‘안전성’ 요건과 관련이 있습니다.
#
# 인간에게 해를 입히는 목적으로 활용해서는 안되며, 오류가 발생하지 않도록 노력해야 합니다.

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; border-color: #d6e9c6; font-weight: bold;"><h2 style='font-weight: bold'>1. 교통표지판 인식 정확도 높이기</h2></div>

# %% [markdown]
# ## **<STEP 1> 티처블 머신으로 교통 표지판 인식 정확도 높이기**

# %% [markdown]
# - 8차시_data1 파일 -> 마우르 오른쪽 버튼 -> 현재 폴더를 아카이브로 다운로드
# - 속도 제한 30과 50 표지판을 구분하는 모델 만들기
# - 잼보드 링크 : https://jamboard.google.com/d/1tcMppdRU0BqpxldmCMnABue44QxXSYVJXlgZJvAywsU/edit?usp=sharing
# - 좌회전 금지와 우회전 금지 표지판을 구분하는 모델 만들기
# - 잼보드 링크 : https://jamboard.google.com/d/14D-FLcWT_zbvqZgwSP7jC9WAyjFV8L1NhyThvPMIO98/edit?usp=sharing
# - 정확도를 높이기 사용한 방법 정리하기

# %% [markdown]
# ## **<STEP 2> 티처블 머신을 통해 만든 모델 이용하기**

# %% [markdown]
# ## 1. 필요한 모듈 임포트하기

# %% [markdown]
# 다음 코드 셀을 실행시켜 모듈을 불러옵니다.

# %%
from keras.models import load_model
from PIL import Image, ImageOps
import numpy as np
# Out:
# 2023-12-01 06:32:47.799573: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-12-01 06:32:47.827938: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## 2. 속도 제한 구분 모델 불러오기

# %% [markdown]
# 티처블 머신을 통해 속도 제한 30과 50 표지판을 구분하는 모델을 만들었습니다.
#
#
# 만든 모델과 레이블을 불러옵니다.

# %%
# Confidence Score 출력할 때 소수점으로 처리하기 위해
np.set_printoptions(suppress=True) 

# 모델 불러오기 (학습시킨 모델)
model1 = load_model("_________________", compile=False)

# 레이블
class_names1 = open("_________________", "r").readlines()

# %% [markdown]
# ## 3. 좌회전/우회전 금지 구분 모델 불러오기

# %% [markdown]
# 티처블 머신을 통해 좌회전 금지와 우회전 금지 표지판을 구분하는 모델을 만들었습니다.
#
#
# 만든 모델과 레이블을 불러옵니다.

# %%
# Confidence Score 출력할 때 소수점으로 처리하기 위해
np.set_printoptions(suppress=True)

# 모델 불러오기 (학습시킨 모델)
model2 = load_model("_________________", compile=False)

# 라벨 
class_names2 = open("_________________", "r").readlines()

# %% [markdown]
# ## 4. 모델 이용하기
# ### 1) 함수 정의
#
# 분류하고자 하는 이미지를 입력받아 분류 결과를 출력하는 함수를 만듭니다.
#
# 이미지를 입력받아 배열 형태로 전처리를 한 후, 모델을 통해 어느 클래스에 속하는 지 예측하는 함수입니다.

# %%
def predict(file, model, class_names):
    # 이미지 전처리
    data = np.ndarray(shape=(_________________), dtype=np.float32) 
    image = Image.open(file).convert("RGB")   
    size = (224, 224)
    image = ImageOps.fit(image, size, Image.Resampling.LANCZOS) 
    image_array = np.asarray(image)  
    normalized_image_array = (image_array.astype(np.float32) / 127.5) - 1   
    data[0] = normalized_image_array
    # 모델 예측
    prediction = _________________   
    index = _________________    
    class_name = _________________
    confidence_score = prediction[0][index]
    # 예측 결과 확인
    image.show()
    print("Class:", class_name[2:], end="")
    print("Confidence Score:", confidence_score)

# %% [markdown]
# ### 2) 함수 호출

# %% [markdown]
# 함수를 호출 할 때는 '이미지 경로', '모델명', '클래스이름'을 전달인자로 입력합니다.
#
# 1) 속도 제한 표지판 모델
#    - 모델명 : model1
#    - 클래스명 : class_names1
# <br>
# 2) 좌회전/우회전 금지 표지판 모델
#       - 모델명 : model2
#    - 클래스명 : class_names2
#
# ※ 주의할 점
# - 이미지 파일의 경로는 '마우스 오른쪽 버튼' - '경로 복사'
#
# - home을 .. 으로 변경
# - ex) 'home/사진.png' -> '../사진.png'

# %%
predict(_________________)

# %% [markdown]
# ## **<STEP 3> 정확도를 높이기 위한 또다른 방법 : 데이터 증강법**

# %% [markdown]
# 데이터의 수가 많지 않기 때문에 적은 수의 이미지에서 모델이 최대한 많은 정보를 뽑아내서 학습할 수 있도록 Augmentation을 적용할 수 있습니다.
#
# Augmentation이란, 이미지를 자르기, 회전, 밝기 조절, 반전, 노이즈 등 임의로 변형하여 가지고있는 이미지의 개수보다 더 많은 이미지를 학습하는 효과를 낼 수 있습니다.
#
# Augmentation을 통해 결과적으로 과대적합을 막아 모델이 학습 데이터에만 맞춰지는 것을 방지하고 새로운 이미지도 잘 분류할 수 있게 만들어 예측 범위도 넓힐 수 있게 됩니다.

# %% [markdown]
# ### 이미지 1장을 이용해서 여러 장으로 증식시켜 보아요.
# 변형하고 싶은 속성을 ImageDataGenerator에 입력합니다.
#
# 원하는 이미지 경로를 입력하여 이미지 데이터를 배열 형태로 변환합니다.
#
# ※ 주의할 점
# - 이미지 파일의 경로는 '마우스 오른쪽 버튼' - '경로 복사'
#
# - home을 .. 으로 변경
# - ex) 'home/사진.png' -> '../사진.png'

# %%
# ImageDataGenerator
datagen = ImageDataGenerator(_________________)

img =image.load_img('_________________', target_size=(150,150))

# 이미지를 배열 형태로 변환
img_arr = _________________

# 4차원 형태로 변환 (150, 150, 3) -> (1, 150, 150, 3)
img_arr =img_arr.reshape((1,) + img_arr.shape)

# %% [markdown]
# flow()를 통해 데이터를 변형합니다.

# %%
fig = plt.figure(figsize=(10,10)) 
ax = list()

# subplot을 생성해서 list 안에 저장
for i in range(20):
    ax.append(fig.add_subplot(4,5,i+1))
    
# batch_size : 한번 호출될 때마다 이미지를 하나씩 가져온다
idx = 0
for batch in _________________(img_arr, batch_size=1) :  
    ax[idx].imshow(_________________(batch[0])) 
    idx += 1
    if idx % 20 == 0 :
        break

plt.tight_layout()
plt.show()
